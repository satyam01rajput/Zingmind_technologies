# %%
# !pip install langchain
# !pip install langchain-ollama
# !pip install streamlit
# !pip install langchain_experimental
# Out:
# Requirement already satisfied: langchain in c:\users\satya\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (0.1.131)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\satya\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\satya\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\satya\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\satya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\satya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\satya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\satya\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\satya\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain) (2.1)
# Collecting langchain-ollama
#   Using cached langchain_ollama-0.2.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain-ollama) (0.3.8)
# Collecting ollama<1,>=0.3.0 (from langchain-ollama)
#   Using cached ollama-0.3.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (0.1.131)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (23.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (8.2.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (4.11.0)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in c:\users\satya\anaconda3\lib\site-packages (from ollama<1,>=0.3.0->langchain-ollama) (0.27.0)
# Requirement already satisfied: anyio in c:\users\satya\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\satya\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\satya\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (1.0.2)
# Requirement already satisfied: idna in c:\users\satya\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (3.7)
# Requirement already satisfied: sniffio in c:\users\satya\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\satya\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\satya\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.32.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\satya\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\satya\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.2.2)
# Using cached langchain_ollama-0.2.0-py3-none-any.whl (14 kB)
# Using cached ollama-0.3.3-py3-none-any.whl (10 kB)
# Installing collected packages: ollama, langchain-ollama
# Successfully installed langchain-ollama-0.2.0 ollama-0.3.3
# Requirement already satisfied: streamlit in c:\users\satya\anaconda3\lib\site-packages (1.32.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (2.32.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\satya\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\satya\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\satya\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\satya\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\satya\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\satya\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\satya\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\satya\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\satya\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\satya\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\satya\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\satya\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\satya\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\satya\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\satya\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\satya\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\satya\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\satya\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Requirement already satisfied: langchain_experimental in c:\users\satya\anaconda3\lib\site-packages (0.3.2)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain_experimental) (0.3.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in c:\users\satya\anaconda3\lib\site-packages (from langchain_experimental) (0.3.8)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.1.131)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (23.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\satya\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (4.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\satya\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\satya\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\satya\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (2.1)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\satya\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\satya\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\satya\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\satya\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\satya\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\satya\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.0.1)
# Requirement already satisfied: anyio in c:\users\satya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\satya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\satya\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\satya\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\satya\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)

# %%
# Out:
#   Cell In[6], line 1
#     Ollama pull llama3.1
#            ^
# SyntaxError: invalid syntax

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM



template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="llama3.1")

chain = prompt | model

print(chain.invoke({"question": "What is artificial intelligence"}))
# Out:
# To break down what artificial intelligence (AI) is, let's consider the concept step by step.
#
# **Step 1: Understanding Intelligence**
# First, we need to understand what "intelligence" means in a human context. Intelligence refers to the ability of humans and some animals to learn from experiences, solve problems, think critically, and adapt to new situations. In other words, it's the capacity to process information effectively and make decisions based on that information.
#
# **Step 2: The Human Brain - A Model for AI**
# The human brain is a complex, powerful, and intricate structure capable of processing vast amounts of information, learning, memory, and decision-making. It serves as a model for what we aim to replicate in artificial intelligence systems.
#
# **Step 3: Defining Artificial Intelligence (AI)**
# Given the definition of intelligence from Step 1, AI can be defined as a computer system that is capable of performing tasks that would typically require human intelligence, such as:
# - Learning (the ability to improve performance on a task over time)
# - Problem-solving
# - Reasoning and making decisions based on data
# - Understanding natural language
#
# **Step 4: Types of Artificial Intelligence**
# There are several types or levels of AI, ranging from simple, rule-based systems that mimic a human decision-making process for specific tasks (like an expert system in a medical context) to more complex forms like machine learning and deep learning. These latter types enable computers to analyze data without being explicitly programmed with the rules for making decisions.
#
# **Step 5: The Role of Data and Algorithms**
# AI works by processing large amounts of data, often using algorithms that allow it to learn from this information. This learning process enables AI systems to adapt and improve their performance over time without needing explicit programming changes.
#
# **Conclusion: Artificial Intelligence in Summary**
# In summary, artificial intelligence is the ability of a computer system or algorithm to perform tasks typically requiring human intelligence, such as problem-solving, decision-making, and learning, through processes like machine learning and deep learning. These capabilities rely on complex algorithms and large amounts of data, allowing AI systems to improve their performance without needing explicit programming changes.
#
# Understanding this step-by-step breakdown should provide a clear overview of what artificial intelligence is and how it works.
